# %%
import polars as pl
import pandas as pd
import re
from tqdm import tqdm
import numpy as np
import networkx as nx
import random

extract_hard = False
extract_medium = False
extract_easy = True

# %%
# import 2 sources
df_concepts = pl.read_parquet("D:/finetune_sbert/pre_with_expression.parquet")
df_relations = pd.read_csv("D:/finetune_sbert/connectivity_2025-04-01.csv")
df_relations['src.id'] = df_relations['src.id'].astype(str)
df_relations['dst.id'] = df_relations['dst.id'].astype(str)
df_relations = pl.from_pandas(df_relations)
# Out:
# C:\Users\yy\AppData\Local\Temp\ipykernel_740\2027641249.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_relations = pd.read_csv("D:/finetune_sbert/connectivity_2025-04-01.csv")

# %%
list_sem_tag = df_concepts['sem_tag'] .unique().to_list() + ["attribute"]
escaped_tags = [re.escape(tag) for tag in list_sem_tag]
pattern = r"\s*\((" + "|".join(escaped_tags) + r")\)"

# %%
df_concepts = (((df_concepts.filter(pl.col("concept_type") == "SCT_PRE")
               .filter(pl.col("status") == "defined")
               .with_columns(pl.col("expression").str.replace_all(r"\d+\|", "|").alias("expression_cleaned")) # remove digits
               ).with_columns(pl.col("expression_cleaned").str.replace_all(pattern, "").alias("expression_cleaned_no_semtag")))
               .with_columns(pl.col("n.label").str.replace_all(pattern, "").alias("label_no_semtag"))
               .unique())

# %%
df_relations_is_a = df_relations.filter(pl.col("type(r)") == "IS_A")
df_concepts_pos = df_concepts.select(pl.col("label_no_semtag"), pl.col("expression_cleaned_no_semtag"), pl.col("id") )
df_relations_is_a_def = ((df_relations_is_a
 .select(pl.col("src.id"),pl.col("dst.id"))
 .join(df_concepts_pos, left_on= "src.id", right_on="id", how="left")
 .drop_nulls()
 .rename({"expression_cleaned_no_semtag": "src.expression_cleaned_no_semtag","label_no_semtag": "src.label_no_semtag"}))
 .join(df_concepts_pos, left_on= "dst.id", right_on="id", how="left")
 .drop_nulls()
 .rename({"expression_cleaned_no_semtag": "dst.expression_cleaned_no_semtag","label_no_semtag": "dst.label_no_semtag"})
 ).unique().select(pl.col("src.id"),pl.col("dst.id"))

# %%
df_concepts.write_csv("D:/finetune_sbert_new/concept_info/concept_info_pre_fully_def_all.csv")

# %%
df_concepts.filter(pl.col("id") == "113091000")['term'].to_list()
# Out:
# ['MRI',
#  'MRI - Magnetic resonance imaging',
#  'Magnetic resonance imaging (procedure)',
#  'Magnetic resonance imaging',
#  'NMR - Nuclear magnetic resonance',
#  'Magnetic resonance study',
#  'MR - Magnetic resonance']

# %% [markdown]
# # build dicts
# - id_to_exp
# - id_to_label (both FSN and synonym)

# %%
id_to_expr = dict(zip(df_concepts["id"], df_concepts["expression_cleaned_no_semtag"]))

df_concept_fsn_syn = df_concepts.group_by("id").agg([
    pl.concat_list([pl.col("label_no_semtag"), pl.col("term")])
      .list.explode()      # Flatten all nested lists into individual elements
      .unique()            # Get unique values             
    .alias("merged_terms")
])
# df_concept_fsn_syn['label_no_semtag'].to_list()
id_to_label_syn = dict(zip(df_concepts["id"], df_concept_fsn_syn["merged_terms"].to_list()))

# %% [markdown]
# # samples

# %%
def hard_triplet(df_concepts, df_relations_is_a_def):
    id_concept = df_concepts["id"].unique()
    seen = set()
    rows_hard = []

    # Build parent -> children and child -> parents maps
    child_to_parents = {}
    parent_to_children = {}

    for row in df_relations_is_a_def.iter_rows(named=True):
        child = row['src.id']
        parent = row['dst.id']
        child_to_parents.setdefault(child, []).append(parent)
        parent_to_children.setdefault(parent, []).append(child)

    for id_anchor in tqdm(id_concept):
        if id_anchor not in child_to_parents:
            continue

        for parent in child_to_parents[id_anchor]:
            siblings = parent_to_children.get(parent, [])
            for sibling_id in siblings:
                if sibling_id == id_anchor:
                    continue
                pair = (id_anchor, sibling_id)
                if pair in seen:
                    continue
                seen.add(pair)
                try:
                    rows_hard.append({
                        "anchor" : id_anchor,
                        "positive": id_anchor,
                        "negative": sibling_id,
                        "level": "hard"
                    })
                except KeyError:
                    continue  # skip missing values

    return rows_hard
rows_hard = hard_triplet(df_concepts, df_relations_is_a_def)
# Out:
# 100%|██████████| 145567/145567 [00:15<00:00, 9132.91it/s]

# %%
def medium_triplet(df_concepts, df_relations_is_a_def):
    df_relations_is_a_def = df_relations_is_a_def.unique()
    src = df_relations_is_a_def['src.id'].to_list()
    dst = df_relations_is_a_def['dst.id'].to_list()

    edges = list(zip(src, dst))
    G = nx.Graph()
    G.add_edges_from(edges)
    
    id_concept = df_concepts["id"].unique()
    id_to_semtag = dict(zip(df_concepts["id"], df_concepts["sem_tag"]))

    rows_medium = []

    for id_anchor in tqdm(id_concept):
        if id_anchor not in G:
            continue

        anchor_tag = id_to_semtag.get(id_anchor)
        if anchor_tag is None:
            continue

        nearby_concepts = nx.single_source_shortest_path_length(G, id_anchor, cutoff=3)
        level_3_candidates = [
            cid for cid, dist in nearby_concepts.items()
            if dist == 3 and id_to_semtag.get(cid) == anchor_tag
        ]
        if not level_3_candidates:
            continue

        sampled_negatives = random.sample(level_3_candidates, min(100, len(level_3_candidates)))

        for candidate_id in sampled_negatives:
            try:
                rows_medium.append({
                    "anchor": id_anchor,
                    "positive": id_anchor,
                    "negative": candidate_id,
                    "level": "medium"
                })
            except KeyError:
                continue  # skip missing data

    return rows_medium

rows_medium = medium_triplet(df_concepts, df_relations_is_a_def)
# Out:
# 100%|██████████| 145567/145567 [02:42<00:00, 898.36it/s]

# %%
def easy_triplet(df_concepts):
    id_concept = df_concepts["id"].unique()
    
    rows_easy = []

    # Build fast access lookup tables
    id_to_top_cat = dict(zip(df_concepts["id"], df_concepts["top_category"]))
  
    # Pre-group concept IDs by top category
    top_cat_to_ids = {}
    for id_, top_cat in id_to_top_cat.items():
        top_cat_to_ids.setdefault(top_cat, []).append(id_)

    # Flatten all IDs once for sampling
    all_ids = set(id_concept)

    for id_anchor in tqdm(id_concept):
        anchor_top_cat = id_to_top_cat.get(id_anchor)
        if anchor_top_cat is None:
            continue

        # Get IDs that are NOT in the same top category
        in_same_cat = set(top_cat_to_ids.get(anchor_top_cat, []))
        negative_candidates = list(all_ids - in_same_cat)

        if not negative_candidates:
            continue

        sampled_negatives = np.random.choice(
            negative_candidates,
            size=min(50, len(negative_candidates)),
            replace=False
        )

        for neg_id in sampled_negatives:
            try:
                rows_easy.append({
                    "anchor": id_anchor,
                    "positive": id_anchor,
                    "negative": neg_id,
                    "level": "easy"
                })
            except KeyError:
                continue  # Skip missing values

    return rows_easy

rows_easy = easy_triplet(df_concepts)
# Out:
#   0%|          | 225/145567 [01:24<15:04:51,  2.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[82], line 50
#      46                 continue  # Skip missing values
#      48     return rows_easy
# ---> 50 rows_easy = easy_triplet(df_concepts)
#
# Cell In[82], line 19, in easy_triplet(df_concepts)
#      16 # Flatten all IDs once for sampling
#      17 all_ids = set(id_concept)
# ---> 19 for id_anchor in tqdm(id_concept):
#      20     anchor_top_cat = id_to_top_cat.get(id_anchor)
#      21     if anchor_top_cat is None:
#
# File c:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\std.py:1188, in tqdm.__iter__(self)
#    1186 dt = cur_t - last_print_t
#    1187 if dt >= mininterval and cur_t >= min_start_t:
# -> 1188     self.update(n - last_print_n)
#    1189     last_print_n = self.last_print_n
#    1190     last_print_t = self.last_print_t
#
# File c:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\std.py:1239, in tqdm.update(self, n)
#    1237     self._ema_dn(dn)
#    1238     self._ema_dt(dt)
# -> 1239 self.refresh(lock_args=self.lock_args)
#    1240 if self.dynamic_miniters:
#    1241     # If no `miniters` was specified, adjust automatically to the
#    1242     # maximum iteration rate seen so far between two prints.
#    1243     # e.g.: After running `tqdm.update(5)`, subsequent
#    1244     # calls to `tqdm.update()` will only cause an update after
#    1245     # at least 5 more iterations.
#    1246     if self.maxinterval and dt >= self.maxinterval:
#
# File c:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\std.py:1344, in tqdm.refresh(self, nolock, lock_args)
#    1342     else:
#    1343         self._lock.acquire()
# -> 1344 self.display()
#    1345 if not nolock:
#    1346     self._lock.release()
#
# File c:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\std.py:1492, in tqdm.display(self, msg, pos)
#    1490 if pos:
#    1491     self.moveto(pos)
# -> 1492 self.sp(self.__str__() if msg is None else msg)
#    1493 if pos:
#    1494     self.moveto(-pos)
#
# File c:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\std.py:347, in tqdm.status_printer.<locals>.print_status(s)
#     345 def print_status(s):
#     346     len_s = disp_len(s)
# --> 347     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     348     last_len[0] = len_s
#
# File c:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\std.py:340, in tqdm.status_printer.<locals>.fp_write(s)
#     339 def fp_write(s):
# --> 340     fp.write(str(s))
#     341     fp_flush()
#
# File c:\Users\yy\AppData\Local\Programs\Python\Python311\Lib\site-packages\tqdm\utils.py:127, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     125 def inner(*args, **kwargs):
#     126     try:
# --> 127         return func(*args, **kwargs)
#     128     except OSError as e:
#     129         if e.errno != 5:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\iostream.py:573, in OutStream.write(self, string)
#     571         self.pub_thread.schedule(self._flush)
#     572     else:
# --> 573         self._schedule_flush()
#     575 return len(string)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\iostream.py:477, in OutStream._schedule_flush(self)
#     474 def _schedule_in_thread():
#     475     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 477 self.pub_thread.schedule(_schedule_in_thread)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\iostream.py:211, in IOPubThread.schedule(self, f)
#     209     self._events.append(f)
#     210     # wake event thread (message content is ignored)
# --> 211     self._event_pipe.send(b"")
#     212 else:
#     213     f()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\zmq\sugar\socket.py:688, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     681         data = zmq.Frame(
#     682             data,
#     683             track=track,
#     684             copy=copy or None,
#     685             copy_threshold=self.copy_threshold,
#     686         )
#     687     data.group = group
# --> 688 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:742, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:789, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:250, in zmq.backend.cython.socket._send_copy()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
rows_medium
# Out:
# [{'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '1290786007',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '1163215007',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '359757004',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '398262004',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '87225004',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '735912006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '30321000175106',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '297961003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '56940005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '723166008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212263005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '609511001',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '125592002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '128477000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '10947971000119108',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '211574000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210786006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '84939004',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '88233000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212262000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '1260223009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '209747006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '209768007',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212229008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '22095002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '10949211000119102',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '283928006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210836006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '29671000175105',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '11995601000119103',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210826003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '282026002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '217681005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '283956001',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '446568009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210851002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '10669711000119102',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210833003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '279420009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '125687005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '283762003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '10947851000119107',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212256005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '363170005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212320009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212230003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '286554000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '49897003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '609501008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '397182009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '211486004',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '127277000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '58990004',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '283714009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '66725002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '314948003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '397187003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210089008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '285801002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '211596006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '733041001',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '7456000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '371058004',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210878000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '830275007',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '430937009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210788007',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '788728009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '30031000175106',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210197003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '860603002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '736256005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '211592008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '1285636009',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '76371008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '262565001',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '10947891000119102',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '211553001',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '105615001',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212228000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '262665008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210869006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '362996001',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212311000',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '211604005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '212192004',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '737346001',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '262577006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '283352008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '10949911000119109',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '301215002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '29298007',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '283906006',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '262833007',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '733234003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '242056005',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '95205002',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '210386008',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '301191003',
#   'level': 'medium'},
#  {'anchor': '239163008',
#   'positive': '239163008',
#   'negative': '10948851000119108',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '119297000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '399460001',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '16216131000119105',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '432059003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309218002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309548003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '128171007',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '110927007',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '16211651000119103',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '446674003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '735198008',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '119341000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '734375004',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '122619005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '734343002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '127469001',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309211008',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309216003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '397456005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '127462005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '29011000087100',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '399492000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '122708000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '734342007',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '1335924000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309132009',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '734417004',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '434244002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309277003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '440137008',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '122640006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '119331003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '432136006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '110928002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '16209851000119100',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309203003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '122573005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309479002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309055005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '734421006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '431361003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '369616003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '423671006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '16213491000119109',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '429832000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '258428005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '40371000087100',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '433120004',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '119371008',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '431884001',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '430408004',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '733101007',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309265008',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '735197003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '734427005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '734426001',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '397455009',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309107007',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '472863002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '399672000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '258462005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '258490009',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '119344008',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '258520000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '110944006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '433309007',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '432657002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309051001',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '127457009',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '431205006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '431404007',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '122601001',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309125000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '258606004',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '119332005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '127460002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309123007',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '257261003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '16215771000119101',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309141004',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '432142005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '122642003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309077009',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '32641000087102',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '33511000087108',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '119376003',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '734341000',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309491006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '309262006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '128158009',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '445367006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '110936006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '441903006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '110954005',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '369618002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '16211211000119102',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '472868006',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '399649002',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '110915009',
#   'level': 'medium'},
#  {'anchor': '271515009',
#   'positive': '271515009',
#   'negative': '446304007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '57243009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '198647008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '40421000119104',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '25341005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '254913005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '11991000119105',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '90493000',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '197770008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '67224007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '722085003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '320681000119102',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '45816000',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '95571006',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '253903007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '61852001',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '48061001',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '204942005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '425879009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '253902002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '55536001',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '371019009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1003861008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '236498004',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '704667004',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '767094002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '97381000119100',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '10812041000119103',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '64283009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '373585009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '71110009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '433183000',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1263950009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '765154003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '7793005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1295482007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '111830007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '371020003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1144973003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '46284005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '86249007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '128606002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '74919005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '128347007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '717958000',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '717754006',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '14178006',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '724480003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '23754003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '48796009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '977021461000119108',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '4181000119109',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1148870007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '722467000',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '31915006',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1922008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '707530009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '77761000',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '722278006',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '274732007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '433036004',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '736992003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '367121000119101',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '32161008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '127013003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '92921005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '197954003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '4985009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '23402009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1144899009',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '253856005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '93052002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '430035004',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '48713002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '12454008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '762263003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '62500006',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '76401000119105',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '204949001',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '27174002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '80375002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '721191000',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1148909008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '722150000',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '197763008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1220648003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '266560008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '268236002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '234348004',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1187546002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '363286005',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '709978007',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '14365001',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '57684003',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '762262008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '13491000119101',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '236690002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '1148933002',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '16726004',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '268854008',
#   'level': 'medium'},
#  {'anchor': '16297002',
#   'positive': '16297002',
#   'negative': '363224005',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '349829005',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '350309002',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '423380000',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '57811004',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '400489006',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '764664004',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '412094003',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '319796006',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '73756003',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '35035001',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '398811007',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '9268004',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '398814004',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '319357003',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774656009',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '421764000',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '400487008',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '412566001',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774928001',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '398683002',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '1193594001',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '398767009',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '419745008',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '33231001',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '346394000',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774667005',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '398724001',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '51073002',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '346359007',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '409311005',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '424102008',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '85990009',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '46709004',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '42444000',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '398649009',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '400819008',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774660007',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774661006',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '767925007',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '768404004',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '764567002',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '763644001',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774662004',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774966003',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '47120002',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '764599008',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '424384000',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774664003',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774663009',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '774949000',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '767923000',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '90332006',
#   'level': 'medium'},
#  {'anchor': '398989001',
#   'positive': '398989001',
#   'negative': '117005003',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '10515002',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '129495007',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '1758005',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '12369008',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '898160006',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '25085002',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '68398003',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '819984003',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '764385008',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '358180008',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '56234005',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '125578008',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '68622003',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '325927008',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '788500001',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '423311006',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '57819002',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '772208008',
#   'level': 'medium'},
#  {'anchor': '776894009',
#   'positive': '776894009',
#   'negative': '715594006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '15051002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '14923004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '20246000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '70383000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '118156007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '738552004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '177853001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '69191006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '27099004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '10985002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '31160006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '47118000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '5722009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '119810006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '82874003',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '410614008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '1230067007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '188383006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '274026006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '1576000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '16453004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '34249006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '307368004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '89862001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '235184005',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '398235007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '118836008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '75087007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '21371007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '174121000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '274348006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '50012009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '1263598005',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '442299008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '238192002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '446739005',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '307506002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '57751008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '80945002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '40330004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '1303995009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '232850000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '287340002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '735184000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '173458002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '74971002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '713046002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '307709007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '11707008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '235304001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '61063002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '235538008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '37245008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '274027002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '27892007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '359572002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '34130000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '176003',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '173977007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '26993008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '35129004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '128401003',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '120072002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '232942008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '112872005',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '54956002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '735018007',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '232776009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '14572004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '119888006',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '38213000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '38497001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '119893009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '232849000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '363123009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '232745003',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '397142002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '112921002',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '276186005',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '1237276005',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '1217364000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '275230005',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '233088008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '238230001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '122465003',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '112817008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '44378008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '107957009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '307655001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '119942001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '87230000',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '119892004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '58204008',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '118753009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '307251001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '17473003',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '235408004',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '1288011001',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '235370009',
#   'level': 'medium'},
#  {'anchor': '41436002',
#   'positive': '41436002',
#   'negative': '386621005',
#   'level': 'medium'},
#  {'anchor': '252829002',
#   'positive': '252829002',
#   'negative': '446332003',
#   'level': 'medium'},
#  {'anchor': '252829002',
#   'positive': '252829002',
#   'negative': '446886003',
#   'level': 'medium'},
#  {'anchor': '252829002',
#   'positive': '252829002',
#   'negative': '284393006',
#   'level': 'medium'},
#  {'anchor': '252829002',
#   'positive': '252829002',
#   'negative': '284370000',
#   'level': 'medium'},
#  {'anchor': '252829002',
#   'positive': '252829002',
#   'negative': '118772009',
#   'level': 'medium'},
#  {'anchor': '252829002',
#   'positive': '252829002',
#   'negative': '77202008',
#   'level': 'medium'},
# ...
#   'negative': '296612008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '291549006',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '271982007',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '291268005',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296533005',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '1148655008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '82782008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '295378004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296030000',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '291703004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '314422000',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '291157004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '291122002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '47191007',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '14154001',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '295749002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '1149145003',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '67438002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296211009',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296405008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '34958009',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '55082002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '295626007',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '290975008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '297019007',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '10385009',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '78695006',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296053004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '291061008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '830282006',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '53796002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296951000',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '290210003',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '73340005',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296235004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296334003',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '295399001',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296851001',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296672000',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '73108003',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '290382004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '297025006',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '290282002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '212738009',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '290524000',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296022001',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '290905007',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '1144778000',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296466007',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296834008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '66491001',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296843004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296454001',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296123008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '291984004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '28504009',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '84393008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '61406000',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296693002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '242824002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '290889002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '12876009',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '295434009',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296446003',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '291785008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296555002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '290980004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '212737004',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '1145546002',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296391008',
#   'level': 'medium'},
#  {'anchor': '291203003',
#   'positive': '291203003',
#   'negative': '296723004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '62294009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '421412005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '415348004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '10712001',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '774494000',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '775397002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '40905005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '774614005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '416392006',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '42082003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '776312003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '703919003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777755009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '441943001',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '776116005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '774445000',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '108986009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '428244004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '416652002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '51992002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777503005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '333367007',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '384706007',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777889002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777402002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '327074002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777500008',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '422675008',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777830009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '774444001',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '776027005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777061004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777409006',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '444907006',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '350634009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777124006',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '774917000',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '326485004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '774617003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777704002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '325824002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '90332006',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '428693003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '416313002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '398857009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '786730003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '789264004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '774654007',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '770938001',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '9778000',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '428186003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '428532001',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '776964002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777881004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '1268483008',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '326488002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '427467001',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '416742007',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '126138002',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '714627007',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '775376003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '409376009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '783691004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '96014005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '783687009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '108936003',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '418250008',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '786231000',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '714777004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '346661005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '421457001',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '773473005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '776415000',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '771585009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '417179007',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '317916006',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '776180006',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '776834006',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '776496000',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777589007',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '395279009',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '363598004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '350469004',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '816003007',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '775722000',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '77048008',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '777613005',
#   'level': 'medium'},
#  {'anchor': '398849006',
#   'positive': '398849006',
#   'negative': '775134003',
#   'level': 'medium'},
#  ...]
